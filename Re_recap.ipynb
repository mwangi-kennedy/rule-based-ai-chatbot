# %% [markdown]
# Pandas on excel.

# %%
import pandas as pd
df=pd.read_excel("Movies_data_2000.xlsx")
df.head()
# Out:
#                      Title     Budget      ID Original Language  Popularity  \
# 0                 Baywatch   69000000  339846                en   35.637691
# 1                 The Wall          0  405775                en   15.597500
# 2                   Gifted    7000000  400928                en   16.025911
# 3          The Spacewalker    7075038  440642                ru   10.181000
# 4  The Fate of the Furious  250000000  337339                en   48.573287
#
#   Release Date     Revenue  Runtime  Vote Average  Vote Count
# 0   2017-12-05   177856751    116.0           6.1        1829
# 1   2017-12-05     1803009     89.0           6.1         117
# 2   2017-12-04    37461045    101.0           7.7         549
# 3   2017-12-04     9868942    140.0           7.4          20
# 4   2017-12-04  1238764765    136.0           6.8        3803

# %%
df["Budget"]
# Out:
# 0        69000000
# 1               0
# 2         7000000
# 3         7075038
# 4       250000000
#           ...
# 4530     25000000
# 4531     10000000
# 4532    103000000
# 4533      6000000
# 4534      1000000
# Name: Budget, Length: 4535, dtype: int64

# %%
df[df["Vote Average"] > 8]
# Out:
#                                               Title     Budget      ID  \
# 115                     In This Corner of the World          0  378108
# 190                                  A Silent Voice          0  378064
# 205                                      Your Name.          0  372058
# 390                                  The Handmaiden    8575000  290098
# 417                           Katyar Kaljat Ghusali    1500000  368330
# 468                                            Room    6000000  264644
# 524                               The Beauty Inside          0  338729
# 725                                       The Guide     722083  293122
# 775                                        Whiplash    3300000  244786
# 791                           The Salt of the Earth          0  265297
# 887                                 Song of the Sea          0  110416
# 908                                           Mommy    4900000  265177
# ...

# %%
print(df.to_string())
# Out:
#                                                                                     Title     Budget      ID Original Language  Popularity Release Date     Revenue  Runtime  Vote Average  Vote Count
# 0                                                                                Baywatch   69000000  339846                en   35.637691   2017-12-05   177856751    116.0           6.1        1829
# 1                                                                                The Wall          0  405775                en   15.597500   2017-12-05     1803009     89.0           6.1         117
# 2                                                                                  Gifted    7000000  400928                en   16.025911   2017-12-04    37461045    101.0           7.7         549
# ...

# %%
df["Budget"].sum()
# Out:
# np.int64(129970141357)

# %%
df["Budget"].count()
# Out:
# np.int64(4535)

# %%
df.isnull().sum()
# Out:
# Title                0
# Budget               0
# ID                   0
# Original Language    0
# Popularity           0
# Release Date         0
# Revenue              0
# Runtime              3
# Vote Average         0
# Vote Count           0
# dtype: int64

# %%
df.dropna()
# Out:
#                                           Title     Budget      ID  \
# 0                                      Baywatch   69000000  339846
# 1                                      The Wall          0  405775
# 2                                        Gifted    7000000  400928
# 3                               The Spacewalker    7075038  440642
# 4                       The Fate of the Furious  250000000  337339
# ...                                         ...        ...     ...
# 4530                        Highlander: Endgame   25000000   12211
# 4531                                     Snatch   10000000     107
# 4532                                  Gladiator  103000000      98
# 4533                                  3 Strikes    6000000   47816
# 4534  The Broken Hearts Club: A Romantic Comedy    1000000   22597
#
#      Original Language  Popularity Release Date     Revenue  Runtime  \
# 0                   en   35.637691   2017-12-05   177856751    116.0
# ...

# %%
df.isnull().sum()
# Out:
# Title                0
# Budget               0
# ID                   0
# Original Language    0
# Popularity           0
# Release Date         0
# Revenue              0
# Runtime              3
# Vote Average         0
# Vote Count           0
# dtype: int64

# %%
df.fillna(0)
# Out:
#                                           Title     Budget      ID  \
# 0                                      Baywatch   69000000  339846
# 1                                      The Wall          0  405775
# 2                                        Gifted    7000000  400928
# 3                               The Spacewalker    7075038  440642
# 4                       The Fate of the Furious  250000000  337339
# ...                                         ...        ...     ...
# 4530                        Highlander: Endgame   25000000   12211
# 4531                                     Snatch   10000000     107
# 4532                                  Gladiator  103000000      98
# 4533                                  3 Strikes    6000000   47816
# 4534  The Broken Hearts Club: A Romantic Comedy    1000000   22597
#
#      Original Language  Popularity Release Date     Revenue  Runtime  \
# 0                   en   35.637691   2017-12-05   177856751    116.0
# ...

# %%
df.isnull().sum()
# Out:
# Title                0
# Budget               0
# ID                   0
# Original Language    0
# Popularity           0
# Release Date         0
# Revenue              0
# Runtime              3
# Vote Average         0
# Vote Count           0
# dtype: int64

# %%
df.isnull()
# Out:
#       Title  Budget     ID  Original Language  Popularity  Release Date  \
# 0     False   False  False              False       False         False
# 1     False   False  False              False       False         False
# 2     False   False  False              False       False         False
# 3     False   False  False              False       False         False
# 4     False   False  False              False       False         False
# ...     ...     ...    ...                ...         ...           ...
# 4530  False   False  False              False       False         False
# 4531  False   False  False              False       False         False
# 4532  False   False  False              False       False         False
# 4533  False   False  False              False       False         False
# 4534  False   False  False              False       False         False
#
#       Revenue  Runtime  Vote Average  Vote Count
# 0       False    False         False       False
# ...

# %%
df.isnull().any()
# Out:
# Title                False
# Budget               False
# ID                   False
# Original Language    False
# Popularity           False
# Release Date         False
# Revenue              False
# Runtime               True
# Vote Average         False
# Vote Count           False
# dtype: bool

# %%
df["Runtime"] = df["Runtime"].fillna(df["Runtime"].mean())

# %%
df.isnull().sum()
# Out:
# Title                0
# Budget               0
# ID                   0
# Original Language    0
# Popularity           0
# Release Date         0
# Revenue              0
# Runtime              0
# Vote Average         0
# Vote Count           0
# dtype: int64

# %%
df.sort_values(by="Runtime", ascending=True)
# Out:
#                                             Title    Budget      ID  \
# 3110                                  Mechenosets   5000000   63838
# 3095                                      Missing         0   52623
# 3949  ? ?¨??¥Ÿ¥?¥?¥Ÿ ???«?? ?¨¥???¥?«¥Ÿ?¯??¥¥?         0  197057
# 1396                    Tutto tutto niente niente   5579750  161545
# 1370               The Worst Christmas of My Life   6843500  147868
# ...                                           ...       ...     ...
# 2803                                 Jodhaa Akbar   8376800   14073
# 3968                            Gods and Generals  56000000   16072
# 4308            Lagaan: Once Upon a Time in India   5200000   19666
# 1538                           Gangs of Wasseypur   1400000  117691
# 2165                                       Carlos  18000000   43434
#
#      Original Language  Popularity Release Date   Revenue  Runtime  \
# 3110                ru    0.414793   2006-12-10   3919731      0.0
# ...

# %%
df.sorted = df.sort_values(by="Budget", ascending=False)
highest_budget_movie = df.sorted.head()
print(highest_budget_movie)
# Out:
#                                             Title     Budget      ID  \
# 1877  Pirates of the Caribbean: On Stranger Tides  380000000    1865
# 3007     Pirates of the Caribbean: At World's End  300000000     285
# 624                       Avengers: Age of Ultron  280000000   99861
# 3249                             Superman Returns  270000000    1452
# 30                  Transformers: The Last Knight  260000000  335988
#
#      Original Language  Popularity Release Date     Revenue  Runtime  \
# 1877                en   27.887720   2011-05-14  1045713802    136.0
# 3007                en   31.363664   2007-05-19   961000000    169.0
# 624                 en   37.379420   2015-04-22  1405403694    141.0
# 3249                en   13.284712   2006-06-28   391081192    154.0
# 30                  en   39.186819   2017-06-21   604942143    149.0
#
#       Vote Average  Vote Count
# 1877           6.4        5068
# 3007           6.9        4627
# 624            7.3        6908
# ...
